# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# %%
from benchmark import run_benchmarks

vertices_range = range(10,40)
times = run_benchmarks(vertices_range, 3)

fig, ax = plt.subplots()
ax.plot(vertices_range, times)
